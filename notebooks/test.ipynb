# %%
import pandas as pd
df = pd.read_csv("C:/Users/holla/PycharmProjects/PythonProject1/failure-prediction-ai/data/ai4i2020.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("C:/Users/holla/PycharmProjects/PythonProject1/failure-prediction-ai/data/ai4i2020.csv")
#
# NameError: name 'pd' is not defined
